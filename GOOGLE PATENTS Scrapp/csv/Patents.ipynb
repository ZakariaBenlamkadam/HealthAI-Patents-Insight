# %%
import pandas as pd

# %%
df = pd.read_csv("patents.csv", error_bad_lines=False)
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_20248\1339345619.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv("patents.csv", error_bad_lines=False)

# %%
df
# Out:
#     Publication_Number                                              Title  \
# 0      US20190339685A1  Methods and systems for data collection, learn...
# 1         US10991463B2  Computer-implemented system and methods for pr...
# 2      US20220375619A1  System, methods, and apparatuses for managing ...
# 3        KR102188766B1  Apparatus for providing artificial intelligenc...
# 4        KR101964733B1  Personalized health care system based on block...
# ..                 ...                                                ...
# 583     WO2023202508A1  Cognitive graph-based general practice patient...
# 584     AU2015243171B2  Methods and compositions for detecting misfold...
# 585    US20140247155A1  Methods using a mobile device to monitor an in...
# 586       US11191423B1  Endoscopic system and methods having real-time...
# 587       CN109754886A  Therapeutic scheme intelligent generating syst...
#
#                                               Abstract  \
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#     Publication_Number                                              Title  \
# 0      US20190339685A1  Methods and systems for data collection, learn...
# 1         US10991463B2  Computer-implemented system and methods for pr...
# 2      US20220375619A1  System, methods, and apparatuses for managing ...
# 3        KR102188766B1  Apparatus for providing artificial intelligenc...
# 4        KR101964733B1  Personalized health care system based on block...
# ..                 ...                                                ...
# 583     WO2023202508A1  Cognitive graph-based general practice patient...
# 584     AU2015243171B2  Methods and compositions for detecting misfold...
# 585    US20140247155A1  Methods using a mobile device to monitor an in...
# 586       US11191423B1  Endoscopic system and methods having real-time...
# 587       CN109754886A  Therapeutic scheme intelligent generating syst...
#
#                                               Abstract  \
# ...

# %%
df['resource'] = 'google patents'

# %%
df.to_csv('Patents_data.csv', index=False)

# %%
df2=pd.read_csv('patent_data5.csv')

# %%
df2
# Out:
#                                                  Title Application Number  \
# 0    DIGITAL TRADITIONAL CHINESE MEDICINE HEALTH DE...          A61B 5/00
# 1    SYSTEM AND METHOD FOR SUPPORTING U-HEALTH BASE...         G16C 10/00
# 2    ARTIFICIAL INTELLIGENCE PERSONALIZED HEALTHCAR...         G06Q 50/22
# 3    HEALTH REPORT GENERATION SYSTEM BASED ON MEDIC...         G16H 15/00
# 4                                     HEALTH VIGOR BAG        A61K 36/899
# ..                                                 ...                ...
# 155  ALLERGENIC PROTEIN AND PEPTIDES FROM HOUSE DUS...         A61K 38/00
# 156  PRIMER AND KIT FOR DETECTING ANGIOSTRONGYLUS C...        C12Q 1/6888
# 157  TEST REAGENT FOR USE IN DIAGNOSIS OF POSTPRAND...         G01N 33/92
# 158  REAGENT AND KIT FOR DETECTING TOXOPLASMA GONDI...        C12Q 1/6893
# 159  REAGENT AND KIT FOR ISOTHERMAL AMPLIFICATION D...        C12Q 1/6844
#
#                                              Applicant               Inventor  \
# ...

# %%
new_columns = {
    'Title': 'Title',
    'Application Number': 'Publication_Number',
    'Applicant': 'Applicant',
    'Inventor': 'Inventors',
    'Abstract': 'Abstact',
    'Number element': 'PDF_Link'
}

# Rename columns
df2.rename(columns=new_columns, inplace=True)

# %%
df2
# Out:
#                                                  Title Publication_Number  \
# 0    DIGITAL TRADITIONAL CHINESE MEDICINE HEALTH DE...          A61B 5/00
# 1    SYSTEM AND METHOD FOR SUPPORTING U-HEALTH BASE...         G16C 10/00
# 2    ARTIFICIAL INTELLIGENCE PERSONALIZED HEALTHCAR...         G06Q 50/22
# 3    HEALTH REPORT GENERATION SYSTEM BASED ON MEDIC...         G16H 15/00
# 4                                     HEALTH VIGOR BAG        A61K 36/899
# ..                                                 ...                ...
# 155  ALLERGENIC PROTEIN AND PEPTIDES FROM HOUSE DUS...         A61K 38/00
# 156  PRIMER AND KIT FOR DETECTING ANGIOSTRONGYLUS C...        C12Q 1/6888
# 157  TEST REAGENT FOR USE IN DIAGNOSIS OF POSTPRAND...         G01N 33/92
# 158  REAGENT AND KIT FOR DETECTING TOXOPLASMA GONDI...        C12Q 1/6893
# 159  REAGENT AND KIT FOR ISOTHERMAL AMPLIFICATION D...        C12Q 1/6844
#
#                                              Applicant              Inventors  \
# ...

# %%
df2['resource'] = 'Espace Net'

# %%
df2
# Out:
#                                                  Title Publication_Number  \
# 0    DIGITAL TRADITIONAL CHINESE MEDICINE HEALTH DE...          A61B 5/00
# 1    SYSTEM AND METHOD FOR SUPPORTING U-HEALTH BASE...         G16C 10/00
# 2    ARTIFICIAL INTELLIGENCE PERSONALIZED HEALTHCAR...         G06Q 50/22
# 3    HEALTH REPORT GENERATION SYSTEM BASED ON MEDIC...         G16H 15/00
# 4                                     HEALTH VIGOR BAG        A61K 36/899
# ..                                                 ...                ...
# 155  ALLERGENIC PROTEIN AND PEPTIDES FROM HOUSE DUS...         A61K 38/00
# 156  PRIMER AND KIT FOR DETECTING ANGIOSTRONGYLUS C...        C12Q 1/6888
# 157  TEST REAGENT FOR USE IN DIAGNOSIS OF POSTPRAND...         G01N 33/92
# 158  REAGENT AND KIT FOR DETECTING TOXOPLASMA GONDI...        C12Q 1/6893
# 159  REAGENT AND KIT FOR ISOTHERMAL AMPLIFICATION D...        C12Q 1/6844
#
#                                              Applicant              Inventors  \
# ...

# %%
df2.to_csv('Patents_data1.csv', index=False)
